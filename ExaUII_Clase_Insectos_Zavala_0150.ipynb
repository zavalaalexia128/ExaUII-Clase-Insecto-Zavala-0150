# %% [markdown]
# <a href="https://colab.research.google.com/github/zavalaalexia128/ExaUII-Clase-Insecto-Zavala-0150/blob/main/ExaUII_Clase_Insectos_Zavala_0150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Zavala Medina NL= 54  Fecha: 30/Abril/2026
#
# #### Crear la clase "Insecto", con 3 atributos (nombre, habitat, tieneAlas)
# #### 2 funciones leerDatos(), mostrarDatos() y 2 objetos (insecto1, insecto2).
# #### que sea interctivo --> input
# #### no usar while true, if, for, lista y diccionarios
#
# ### Insectos
# ![](https://raw.githubusercontent.com/zavalaalexia128/ExaUII-Clase-Insecto-Zavala-0150/refs/heads/main/InfoClaseinsectos.png)

# %%
# Clase Insecto, atributos: nombre, habitat, tieneAlas
# funciones leerDatos(), mostrarDatos()
# crear 2 objetos insecto1, insecto2

class Insecto:
    def __init__(self, nombre=None, habitat=None, tieneAlas=None):
        self.nombre = nombre
        self.habitat = habitat
        self.tieneAlas = tieneAlas

    def leerDatos(self):
        self.nombre = input("Ingrese el nombre del insecto: ")
        self.habitat = input("Ingrese el hábitat del insecto: ")
        self.tieneAlas = input("¿Tiene alas? (Si/No): ")
        return self.nombre, self.habitat, self.tieneAlas

    def mostrarDatos(self):
        print(f"Nombre: {self.nombre}")
        print(f"Hábitat: {self.habitat}")
        print(f"Tiene alas: {self.tieneAlas}")
        return self.nombre, self.habitat, self.tieneAlas

# --- Registro de Objetos ---

print("--- Registro de Insecto Numero 1 ---")
insecto1 = Insecto()
insecto1.leerDatos()
insecto1.mostrarDatos()
print(". ݁₊ ⊹ . ݁˖ . ݁")

print("--- Registro de Insecto Numero 2 ---")
insecto2 = Insecto()
insecto2.leerDatos()
insecto2.mostrarDatos()
print(". ݁₊ ⊹ . ݁˖ . ݁")

print("Software realizado por Zavala Medina Alexia Paola NL = 54")
# Out:
# --- Registro de Insecto Numero 1 ---
# Ingrese el nombre del insecto: Mantis religiosa
# Ingrese el hábitat del insecto: Climas templados y tropicales
# ¿Tiene alas? (Si/No): Si
# Nombre: Mantis religiosa
# Hábitat: Climas templados y tropicales
# Tiene alas: Si
# . ݁₊ ⊹ . ݁˖ . ݁
# --- Registro de Insecto Numero 2 ---
# Ingrese el nombre del insecto: Oruga
# Ingrese el hábitat del insecto: Plantas y arboles
# ¿Tiene alas? (Si/No): No
# Nombre: Oruga
# Hábitat: Plantas y arboles
# Tiene alas: No
# . ݁₊ ⊹ . ݁˖ . ݁
# Software realizado por Zavala Medina Alexia Paola NL = 54

# %% [markdown]
# ![](https://raw.githubusercontent.com/zavalaalexia128/ExaUII-Clase-Insecto-Zavala-0150/refs/heads/main/RelacionCodigo.PNG)
